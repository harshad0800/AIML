# %%
print("Hello and Welcome to AIML Lab...This is Dhruva here!")
# Out:
# Hello and Welcome to AIML Lab...This is Dhruva here!

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
username = input("Enter Username: ")
print("Username is: "+username)
# Out:
# Enter Username: DhruvaP
# Username is: DhruvaP

# %%
#print which number is larger
if 10 > 5:
  print("10 is greater than 5")
# Out:
# 10 is greater than 5

# %%
a = 5
b = 1.5
c = 23+2j
d = 'abcd'
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>

# %%
x,y,z = "Cricket" , "Football" , "Tennis"
print(x)
print(y)
print(z)
# Out:
# Cricket
# Football
# Tennis

# %%
name = "Dhruva Parmar"
print(len(name))
# Out:
# 13

# %%
#looping through a string
for x in "Mumbai":
  print(x)
# Out:
# M
# u
# m
# b
# a
# i

# %%
#slicing
b = "Hello World"
print(b[:4])
# Out:
# Hell

# %%
b = "Hello World"
print(b[6:])
# Out:
# World

# %%
b = "Hello World"
print(b[3:7])
# Out:
# lo W

# %%
#slicing stride
b = "WelcometoTIMSCDR"
print(b[::2])
# Out:
# WloeoISD

# %%
a = "w"
print(type(a))
# Out:
# <class 'str'>

# %%
#creating lists
my_list = []
my_list1 = [1,2,3,4]#integers
my_list2 = [1,"Hello",1.5,23+3j] #different datatypes
my_list3 = ["key", [1,2,3],["a"]] #list with nested datatypes

print(my_list)
print(my_list1)
print(my_list2)
print(my_list3)
# Out:
# []
# [1, 2, 3, 4]
# [1, 'Hello', 1.5, (23+3j)]
# ['key', [1, 2, 3], ['a']]

# %%
my_list1 = [1,2,3,4]
print(my_list1[1])
# Out:
# 2

# %%
#nested indexing
n_list = ["Happy", [2,1,0,4],['key','welcome','hello']]
print(n_list[0][1])
print(n_list[2][2])
print(n_list[1][3])
print(n_list[2][0][1])
# Out:
# a
# hello
# 4
# e

# %%
#negative indexing
my_list = ['p','r','o','b','e']
print(my_list[-3])
print(my_list[-4])
# Out:
# o
# r

# %%
#list slicing
my_list = ['e','l','e','p','h','a','n','t']
print(my_list[2:4])
print(my_list[:5])
print(my_list[5:])
# Out:
# ['e', 'p']
# ['e', 'l', 'e', 'p', 'h']
# ['a', 'n', 't']

# %%
#list slicing(negative)
my_list = ['e','l','e','p','h','a','n','t']
print(my_list[2:-2])
print(my_list[:-2])
print(my_list[-2:])
# Out:
# ['e', 'p', 'h', 'a']
# ['e', 'l', 'e', 'p', 'h', 'a']
# ['n', 't']

# %%
odd = [2,4,6,8]
print(odd)
odd[1:3] = [33,44]
print(odd)
odd[0]=1
print(odd)
# Out:
# [2, 4, 6, 8]
# [2, 33, 44, 8]
# [1, 33, 44, 8]

# %%
#append

odd = [1,2,3]
odd.append(9) #add only 1 element
print(odd)

odd.extend([9,10,11,12,13,14]) #add n no of elements
print(odd)

odd.insert(3,7) #insert(position,value)
print(odd)
# Out:
# [1, 2, 3, 9]
# [1, 2, 3, 9, 9, 10, 11, 12, 13, 14]
# [1, 2, 3, 7, 9, 9, 10, 11, 12, 13, 14]

# %%
my_list = ['e','l','e','a','p','h','a','n','t']
del my_list[3]
print(my_list)

del my_list[1:3]
print(my_list)
# Out:
# ['e', 'l', 'e', 'p', 'h', 'a', 'n', 't']
# ['e', 'p', 'h', 'a', 'n', 't']

# %%
my_list = ['e','l','e','a','p','h','a','n','t']
my_list.remove('a')
print(my_list)
print(my_list.pop(2))
print(my_list)
# Out:
# ['e', 'l', 'e', 'p', 'h', 'a', 'n', 't']
# e
# ['e', 'l', 'p', 'h', 'a', 'n', 't']

# %%
my_list = [7,2,4,6,1,3,9]
print(my_list.index(1))

my_list.sort()
print(my_list)

my_list.reverse()
print(my_list)
# Out:
# 4
# [1, 2, 3, 4, 6, 7, 9]
# [9, 7, 6, 4, 3, 2, 1]

# %%
pow2 = [3 ** x for x in range(7)]
print(pow2)
# Out:
# [1, 3, 9, 27, 81, 243, 729]

# %%
x = min(10,20,30)
print(x)

y = max(221,202,199)
print(y)
# Out:
# 10
# 221

# %%
x = abs(-5.5)
print(x)
# Out:
# 5.5

# %%
x = pow(4,3)
print(x)
# Out:
# 64

# %%
import math
x = math.sqrt(144)
print(x)
# Out:
# 12.0

# %%
x = math.pi
b = 10 * x
print(b)
# Out:
# 31.41592653589793

# %%
import math
r = float(input("Enter the Radius of the Circle:"))
pii = math.pi
area = pii * r * r
print("Area of Circle is:%.2f" %area)
# Out:
# Enter the Radius of the Circle:7
# Area of Circle is:153.94
